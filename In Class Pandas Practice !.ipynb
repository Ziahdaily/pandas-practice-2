# %% [markdown]
# # In Class Pandas Practice
#
# ## Ziah Daily
#
# ### October 4th, 2019

# %%
# Import all the modules I want to use in this homework, so they are visible to my notebook.Makes pandas accesible and shortens it to pd.
import pandas as pd

# %%
#creating the dataframe
my_df = pd.read_csv("nba.csv")

# %%
my_df.tail(4)
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26   3-Jun     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24   1-Jun     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26   3-Jul     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26  Jul-00     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
my_df.head(3)
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  5-Jun     205
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %% [markdown]
# ###First look at groupby() function
#
# simple group of my data on the Team column

# %%
#applying groupby() function to 
#group the data on team value
# the groupby is group all the teams...
gk = my_df.groupby('Team')

#Lets print the first entries
#in all the groups formed
gk.first()
# Out:
#                                          Name  Number Position  Age  Height  \
# Team
# Atlanta Hawks                   Kent Bazemore      24       SF   26   5-Jun
# Boston Celtics                  Avery Bradley       0       PG   25   2-Jun
# Brooklyn Nets                Bojan Bogdanovic      44       SG   27   8-Jun
# Charlotte Hornets               Nicolas Batum       5       SG   27   8-Jun
# Chicago Bulls                Cameron Bairstow      41       PF   25   9-Jun
# Cleveland Cavaliers       Matthew Dellavedova       8       PG   25   4-Jun
# Dallas Mavericks              Justin Anderson       1       SG   22   6-Jun
# Denver Nuggets                 Darrell Arthur       0       PF   28   9-Jun
# Detroit Pistons                  Joel Anthony      50        C   33   9-Jun
# Golden State Warriors         Leandro Barbosa      19       SG   33   3-Jun
# Houston Rockets                  Trevor Ariza       1       SF   30   8-Jun
# ...

# %%
my_df.describe()
# Out:
# /Users/ziahgraceolivadaily/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000           NaN
# 50%     13.000000   26.000000  220.000000           NaN
# 75%     25.000000   30.000000  240.000000           NaN
# max     99.000000   40.000000  307.000000  2.500000e+07

# %% [markdown]
# type tells me the data type of the variable. In this case we confirmed tht my_df is actually a data frame.

# %%
type(my_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# This code below shows

# %%
my_df.index
# Out:
# RangeIndex(start=0, stop=457, step=1)

# %%
my_df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %% [markdown]
# the code below provides a handful of data on number of rows, column names,

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null int64
# Position    457 non-null object
# Age         457 non-null int64
# Height      457 non-null object
# Weight      457 non-null int64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.2+ KB

# %% [markdown]
# transposed matrix

# %%
trans_df = my_df.T
trans_df
# Out:
#                      0               1                  2               3    \
# Name       Avery Bradley     Jae Crowder       John Holland     R.J. Hunter
# Team      Boston Celtics  Boston Celtics     Boston Celtics  Boston Celtics
# Number                 0              99                 30              28
# Position              PG              SF                 SG              SG
# Age                   25              25                 27              22
# Height             2-Jun           6-Jun              5-Jun           5-Jun
# Weight               180             235                205             185
# College            Texas       Marquette  Boston University   Georgia State
# Salary       7.73034e+06     6.79612e+06                NaN     1.14864e+06
#
#                      4               5               6               7    \
# Name       Jonas Jerebko    Amir Johnson   Jordan Mickey    Kelly Olynyk
# ...

# %%
#finding the values contained in the "portland Trail Blazers" group
gk.get_group('Portland Trail Blazers')
# Out:
#      Age           College  Height              Name  Number Position  \
# 427   20            Kansas   8-Jun   Cliff Alexander      34       PF
# 428   25       Wake Forest   9-Jun   Al-Farouq Aminu       8       SF
# 429   23        Notre Dame   5-Jun   Pat Connaughton       5       SG
# 430   24        California   6-Jun      Allen Crabbe      23       SG
# 431   27    North Carolina  10-Jun          Ed Davis      17        C
# 432   23        St. John's   9-Jun  Maurice Harkless       4       SF
# 433   28              Duke   5-Jun  Gerald Henderson       9       SG
# 434   34  Central Michigan  Jul-00       Chris Kaman      35        C
# 435   24          Illinois   1-Jul    Meyers Leonard      11       PF
# 436   25       Weber State   3-Jun    Damian Lillard       0       PG
# 437   24            Lehigh   4-Jun     C.J. McCollum       3       SG
# 438   23    Westchester CC   7-Jun      Luis Montero      44       SG
# ...

# %%
gk.get_group('Portland Trail Blazers').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 427 to 441
# Data columns (total 8 columns):
# Age         15 non-null int64
# College     15 non-null object
# Height      15 non-null object
# Name        15 non-null object
# Number      15 non-null int64
# Position    15 non-null object
# Salary      15 non-null float64
# Weight      15 non-null int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 1.1+ KB

# %%
gk.get_group('Portland Trail Blazers').describe()
# Out:
#              Age     Number        Salary      Weight
# count  15.000000  15.000000  1.500000e+01   15.000000
# mean   25.066667  16.000000  3.220121e+06  218.600000
# std     3.634491  13.711309  2.392741e+06   25.178789
# min    20.000000   0.000000  5.250930e+05  173.000000
# 25%    23.000000   4.500000  1.181398e+06  203.000000
# 50%    24.000000  11.000000  2.854940e+06  215.000000
# 75%    26.500000  23.500000  4.626144e+06  240.000000
# max    34.000000  44.000000  8.042895e+06  265.000000
